# %% [markdown]
# # **유클리드 거리(Euclidean distance)**
# 두 점 사이의 거리를 계산
# ![화면 캡처 2022-05-23 135450.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
def dist(x, y):
  return np.sqrt(np.sum((x-y)**2))

# %%
doc1 = np.array((2,3,0,1))
doc2 = np.array((1,2,3,1))
doc3 = np.array((2,1,2,2))
docQ = np.array((1,1,0,1))

print('문서1과 문서Q의 거리 :',dist(doc1,docQ))
print('문서2과 문서Q의 거리 :',dist(doc2,docQ))
print('문서3과 문서Q의 거리 :',dist(doc3,docQ))
# Out:
# 문서1과 문서Q의 거리 : 2.23606797749979
# 문서2과 문서Q의 거리 : 3.1622776601683795
# 문서3과 문서Q의 거리 : 2.449489742783178

# %% [markdown]
# # **자카드 유사도(Jaccard similarity)**
# 합집합에서 교집합의 비율을 구하는 것
# 0과 1 사이의 값을 가지며 만약 두 집합이 동일하다면 1의 값을 가지고 두 집합의 공통 원소가 없다면 0의 값을 갖는다.
# ![화면 캡처 2022-05-23 140457.png](data:image/png;base64,...)

# %%
doc1 = "apple banana everyone like likey watch card holder"
doc2 = "apple banana coupon passport love you"

# 토큰화
tokenized_doc1 = doc1.split()
tokenized_doc2 = doc2.split()

print('문서1 :',tokenized_doc1)
print('문서2 :',tokenized_doc2)
# Out:
# 문서1 : ['apple', 'banana', 'everyone', 'like', 'likey', 'watch', 'card', 'holder']
# 문서2 : ['apple', 'banana', 'coupon', 'passport', 'love', 'you']

# %%
# 합집합
union = set(tokenized_doc1).union(set(tokenized_doc2))
print('문서1과 문서2의 합집합 :',union)

# 교집합
intersection = set(tokenized_doc1).intersection(set(tokenized_doc2))
print('문서1과 문서2의 교집합 :',intersection)

# 자카드 유사도
print('자카드 유사도 :',len(intersection)/len(union))
# Out:
# 문서1과 문서2의 합집합 : {'you', 'apple', 'watch', 'holder', 'like', 'likey', 'passport', 'love', 'everyone', 'coupon', 'card', 'banana'}
# 문서1과 문서2의 교집합 : {'apple', 'banana'}
# 자카드 유사도 : 0.16666666666666666
