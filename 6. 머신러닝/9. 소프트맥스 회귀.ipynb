# %% [markdown]
# # **다중 클래스 분류(Multi-class Classification)**
# 이진 분류가 두 개의 선택지 중 하나를 고르는 문제였다면, 세 개 이상의 선택지 중 하나를 고르는 문제를 다중 클래스 분류라고 한다.

# %% [markdown]
# # **소프트맥스 함수(Sotfmax function)**
# 소프트맥스 함수는 선택해야 하는 선택지의 총 개수를 k라고 할 때, k차원의 벡터를 입력받아 각 클래스에 대한 확률을 추정한다.
# ![화면 캡처 2022-05-25 214835.png](data:image/png;base64,...)

# %% [markdown]
# 분류하고자 하는 클래스가 k개일 때, k차원의 벡터를 입력받아서 모든 벡터 원소의 값을 0과 1 사이의 값으로 값을 변경하여 다시 k 차원의 벡터로 반환한다.
# ![화면 캡처 2022-05-25 215020.png](data:image/png;base64,...)

# %% [markdown]
# **- 샘플 데이터 벡터를 소프트맥스 함수의 입력 벡터로 차원을 축소하는 방법**
# 소프트맥스 함수의 입력 벡터 z의 차원수만큼 결과값이 나오도록 가중치 곱을 진행한다.
# 학습 과정에서 점차적으로 오차를 최소화하는 가중치로 값이 변경된다.
# **- 비용 함수**
# 소프트맥스 회귀는 비용 함수로 크로스 엔트로피 함수를 사용한다.
# 오차로부터 가중치를 업데이트한다.

# %% [markdown]
# # **원-핫 벡터의 무작위성**
# 각 클래스가 순서의 의미를 갖고 있어서 회귀를 통해서 분류 문제를 풀 수 있을 경우 정수 인코딩의 순서 정보가 도움이 된다.
# 하지만 일반적인 분류 문제에서는 각 클래스는 순서의 의미를 갖고 있지 않으므로 각 클래스 간의 오차는 균등한 것이 옳다.
# 정수 인코딩과 달리 원-핫 인코딩은 분류 문제 모든 클래스 간의 관계를 균등하게 분배한다.
# 원-핫 벡터의 관계의 무작위성은 때로는 단어의 유사성을 구할 수 없다는 단점으로 언급될 수 있다.

# %% [markdown]
# # **비용 함수**
# ### **크로스 엔트로피 함수**
# ![화면 캡처 2022-05-25 215854.png](data:image/png;base64,...)
# (y : 실제값, k : 클래스의 개수, y_j : 실제값 원-핫 벡터의 j번째 인덱스, p_j : 샘플데이터가 j번째 클래스일 확률)
#
# **n개 전체 데이터에 대한 평균**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
