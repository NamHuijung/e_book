# %% [markdown]
# **패딩**
# 자연어 처리를 하다보면 각 문장(또는 문서)은 서로 길이가 다를 수 있다.
# 병렬 연산을 위해서 여러 문장의 길이를 임의로 동일하게 맞춰주는 작업이 필요하다.

# %% [markdown]
# # **Numpy로 패딩하기**

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
preprocessed_sentences = [['barber', 'person'], ['barber', 'good', 'person'], ['barber', 'huge', 'person'], ['knew', 'secret'], ['secret', 'kept', 'huge', 'secret'], ['huge', 'secret'], ['barber', 'kept', 'word'], ['barber', 'kept', 'word'], ['barber', 'kept', 'secret'], ['keeping', 'keeping', 'huge', 'secret', 'driving', 'barber', 'crazy'], ['barber', 'went', 'huge', 'mountain']]

# %%
# 단어 집합을 만들고 정수 인코딩을 수행
# 모든 단어가 고유한 정수로 변환
tokenizer = Tokenizer()
tokenizer.fit_on_texts(preprocessed_sentences)
encoded = tokenizer.texts_to_sequences(preprocessed_sentences)
print(encoded)
# Out:
# [[1, 5], [1, 8, 5], [1, 3, 5], [9, 2], [2, 4, 3, 2], [3, 2], [1, 4, 6], [1, 4, 6], [1, 4, 2], [7, 7, 3, 2, 10, 1, 11], [1, 12, 3, 13]]

# %%
# 모두 동일한 길이로 맞춰주기 위해서 이 중에서 가장 길이가 긴 문장의 길이를 계산
max_len = max(len(item) for item in encoded)
print("최대 길이 :", max_len)
# Out:
# 최대 길이 : 7

# %%
# 모든 문장의 길이를 7로 맞추기
# 가상의 단어 "PAD"
# "PAD"라는 단어가 있다고 가정하고 이 단어는 0번 단어라고 정의
for sentence in encoded:
    while len(sentence) < max_len:
        sentence.append(0)

padded_np = np.array(encoded)
print(padded_np)
# Out:
# [[ 1  5  0  0  0  0  0]
#  [ 1  8  5  0  0  0  0]
#  [ 1  3  5  0  0  0  0]
#  [ 9  2  0  0  0  0  0]
#  [ 2  4  3  2  0  0  0]
#  [ 3  2  0  0  0  0  0]
#  [ 1  4  6  0  0  0  0]
#  [ 1  4  6  0  0  0  0]
#  [ 1  4  2  0  0  0  0]
#  [ 7  7  3  2 10  1 11]
#  [ 1 12  3 13  0  0  0]]

# %% [markdown]
# 0번 단어는 사실 아무런 의미도 없는 단어이기 때문에 자연어 처리하는 과정에서 기계는 0번 단어를 무시하게 될 것이다.
# 이와 같이 데이터에 특정 값을 채워서 데이터의 크기(shape)를 조정하는 것을 패딩(padding)이라고 한다.
# 숫자 0을 사용하고 있다면 제로 패딩(zero padding)이라고 한다.

# %% [markdown]
# # 케라스 전처리 도구로 패딩하기

# %% [markdown]
# 케라스에서는 위와 같은 패딩을 위해 pad_sequences()를 제공한다.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
encoded = tokenizer.texts_to_sequences(preprocessed_sentences)
print(encoded)
# Out:
# [[1, 5], [1, 8, 5], [1, 3, 5], [9, 2], [2, 4, 3, 2], [3, 2], [1, 4, 6], [1, 4, 6], [1, 4, 2], [7, 7, 3, 2, 10, 1, 11], [1, 12, 3, 13]]

# %%
# 케라스의 pad_sequences를 사용해서 패딩
# Numpy로 패딩을 진행하였을 때와 다른 이유는
# pad_sequences는 기본적으로 문서의 뒤에 0을 채우는 것이 아니라 앞에 0으로 채우기 때문이다.
padded = pad_sequences(encoded)
print(padded)
# Out:
# [[ 0  0  0  0  0  1  5]
#  [ 0  0  0  0  1  8  5]
#  [ 0  0  0  0  1  3  5]
#  [ 0  0  0  0  0  9  2]
#  [ 0  0  0  2  4  3  2]
#  [ 0  0  0  0  0  3  2]
#  [ 0  0  0  0  1  4  6]
#  [ 0  0  0  0  1  4  6]
#  [ 0  0  0  0  1  4  2]
#  [ 7  7  3  2 10  1 11]
#  [ 0  0  0  1 12  3 13]]

# %%
# 뒤에 0을 채우고 싶다면 인자로 padding='post'를 주면 된다.
padded = pad_sequences(encoded, padding='post')
print(padded)
# Out:
# [[ 1  5  0  0  0  0  0]
#  [ 1  8  5  0  0  0  0]
#  [ 1  3  5  0  0  0  0]
#  [ 9  2  0  0  0  0  0]
#  [ 2  4  3  2  0  0  0]
#  [ 3  2  0  0  0  0  0]
#  [ 1  4  6  0  0  0  0]
#  [ 1  4  6  0  0  0  0]
#  [ 1  4  2  0  0  0  0]
#  [ 7  7  3  2 10  1 11]
#  [ 1 12  3 13  0  0  0]]

# %%
# 실제 결과가 동일한지 비교
(padded == padded_np).all()
# Out:
# True

# %%
# maxlen의 인자로 정수를 주면, 해당 정수로 모든 문서의 길이를 동일하게 한다.
# 기존 5보다 길었다면 데이터가 손실된다.
# 앞의 단어가 삭제됨
padded = pad_sequences(encoded, padding="post", maxlen=5)
print(padded)
# Out:
# [[ 1  5  0  0  0]
#  [ 1  8  5  0  0]
#  [ 1  3  5  0  0]
#  [ 9  2  0  0  0]
#  [ 2  4  3  2  0]
#  [ 3  2  0  0  0]
#  [ 1  4  6  0  0]
#  [ 1  4  6  0  0]
#  [ 1  4  2  0  0]
#  [ 3  2 10  1 11]
#  [ 1 12  3 13  0]]

# %%
# 앞의 단어가 아니라 뒤의 단어가 삭제되도록 하고 싶다면 truncating이라는 인자를 사용한다.
padded = pad_sequences(encoded, padding='post', truncating='post', maxlen=5)
print(padded)
# Out:
# [[ 1  5  0  0  0]
#  [ 1  8  5  0  0]
#  [ 1  3  5  0  0]
#  [ 9  2  0  0  0]
#  [ 2  4  3  2  0]
#  [ 3  2  0  0  0]
#  [ 1  4  6  0  0]
#  [ 1  4  6  0  0]
#  [ 1  4  2  0  0]
#  [ 7  7  3  2 10]
#  [ 1 12  3 13  0]]

# %%
# 숫자 0이 아니라 다른 숫자를 패딩을 위한 숫자로 사용할 수도 있다.
# 현재 사용된 정수들과 겹치지 않도록, 단어 집합의 크기에 +1을 한 숫자로 사용

# 현재 단어가 총 13개
last_value = len(tokenizer.word_index) + 1 # 단어 집합의 크기보다 1 큰 숫자를 사용
print(last_value)
# Out:
# 14

# %%
padded = pad_sequences(encoded, padding='post', value=last_value)
print(padded)
# Out:
# [[ 1  5 14 14 14 14 14]
#  [ 1  8  5 14 14 14 14]
#  [ 1  3  5 14 14 14 14]
#  [ 9  2 14 14 14 14 14]
#  [ 2  4  3  2 14 14 14]
#  [ 3  2 14 14 14 14 14]
#  [ 1  4  6 14 14 14 14]
#  [ 1  4  6 14 14 14 14]
#  [ 1  4  2 14 14 14 14]
#  [ 7  7  3  2 10  1 11]
#  [ 1 12  3 13 14 14 14]]
